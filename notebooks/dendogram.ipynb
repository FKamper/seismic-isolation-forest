# %% [markdown]
# Illustration for constructing a dendogram using the segment DTW approach.

# %%
import os
import numpy as np
import pandas as pd

from joblib import load
from datamod.loading_utils import preproc_flow_annotations, read_segment

# %%
folder = "../data/XP/2018/ILL11/HHZ.D/"
stream_paths = [folder + f for f in os.listdir(folder) if not f.startswith("._")]
stream_paths = np.array(sorted(stream_paths, key=lambda f: int(f.rsplit(".", 1)[-1])))

if_mod = load("../output/if_models/ILL11_illustration.joblib")

if_segments = preproc_flow_annotations(
    pd.read_csv("../output/if_segments/ILL11_illustration.csv", index_col=0)
)

# %%
dist_matrix = np.zeros([if_segments.shape[0], if_segments.shape[0]])

# %%
for i in range(dist_matrix.shape[0]):
    seg1 = read_segment(if_segments["start"][i], if_segments["stop"][i], stream_paths)
    for j in range(dist_matrix.shape[0]):
        if i >= j:
            continue

        if dist_matrix[i, j] > 0:
            continue

        seg2 = read_segment(
            if_segments["start"][j], if_segments["stop"][j], stream_paths
        )
        dist_matrix[i, j] = np.median(segment_dtw(seg1, seg2, if_mod))
# Out:
# 52.0 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 11
#       8     continue
#      10 seg2 = read_segment(if_segments["start"][j],if_segments["stop"][j],stream_paths)
# ---> 11 dist_matrix[i,j] = np.median(segment_dtw(seg1, seg2, if_mod))
#
# Cell In[65], line 19, in segment_dtw(seg1, seg2, if_mod, window_size, stride)
#      16     y = X2[path[i][1],:]
#      17     y = (y - np.mean(y))/np.std(y)
# ---> 19     dtw_dists.append(fastdtw(x,y)[0]
#      20     )
#      22 return dtw_dists
#
# File c:\Users\franc\anaconda3\envs\seismic-if-env\lib\site-packages\fastdtw\fastdtw.py:53, in fastdtw(x, y, radius, dist)
#      16 ''' return the approximate distance between 2 time series with O(N)
#      17     time and memory complexity
#      18
#    (...)
#      50     (2.0, [(0, 0), (1, 0), (2, 1), (3, 2), (4, 2)])
#      51 '''
#      52 x, y, dist = __prep_inputs(x, y, dist)
# ---> 53 return __fastdtw(x, y, radius, dist)
#
# File c:\Users\franc\anaconda3\envs\seismic-if-env\lib\site-packages\fastdtw\fastdtw.py:74, in __fastdtw(x, y, radius, dist)
#      71 y_shrinked = __reduce_by_half(y)
#      72 distance, path = \
#      73     __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
# ---> 74 window = __expand_window(path, len(x), len(y), radius)
#      75 return __dtw(x, y, window, dist=dist)
#
# File c:\Users\franc\anaconda3\envs\seismic-if-env\lib\site-packages\fastdtw\fastdtw.py:178, in __expand_window(path, len_x, len_y, radius)
#     176 if (i, j) in window_:
#     177     window.append((i, j))
# --> 178     if new_start_j is None:
#     179         new_start_j = j
#     180 elif new_start_j is not None:
#
# KeyboardInterrupt:
